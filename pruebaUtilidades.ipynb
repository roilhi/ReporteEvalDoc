# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dfAllData = pd.read_csv('Puntuacionestotal.csv')
dfPromedios = pd.read_csv('promedioPuntuaciones.csv')

# %%
dfPromedios.head()
# Out:
#                          Docente  Pregunta_1  Pregunta_2  Pregunta_3  \
# 0  ABEL NOÉ BETANCOURT DEL ÁNGEL    3.263158    3.368421    3.368421
# 1   ALFONSO MOISES GÓMEZ DEL RIO    3.166667    3.333333    2.833333
# 2          ALHELI DURAZO VÁZQUEZ    4.000000    4.000000    4.000000
# 3        ANA LUISA CHÁVEZ GARCÍA    3.600000    4.000000    3.800000
# 4          ARACELI RAMIREZ REYES    3.000000    3.000000    4.000000
#
#    Pregunta_4  Pregunta_5  Pregunta_6  Pregunta_7  Pregunta_8  Pregunta_9  \
# 0    3.421053    3.315789    3.315789    3.526316    3.368421    3.473684
# 1    3.666667    3.333333    3.166667    3.166667    3.000000    3.166667
# 2    4.000000    4.000000    3.875000    3.875000    4.000000    4.000000
# 3    4.000000    3.400000    4.000000    3.200000    3.400000    3.400000
# 4    4.000000    3.000000    3.000000    3.000000    3.000000    3.000000
#
#    Pregunta_10
# 0     3.368421
# 1     3.666667
# 2     4.000000
# 3     3.800000
# 4     4.000000

# %%
#csfont()
Ydata = list(dfPromedios.iloc[0,:])[1:]
Xdata = dfPromedios.columns.values.tolist()[1:]
colors = plt.cm.Reds(np.linspace(0.35,0.65))
plt.barh(Xdata,Ydata, color=colors)
plt.title(dfPromedios.iloc[0,:][0])
plt.xticks(rotation=90)
plt.show()

# %%
list(dfPromedios.iloc[0,:])[1:]
# Out:
# [3.263157894736842,
#  3.3684210526315788,
#  3.3684210526315788,
#  3.421052631578948,
#  3.3157894736842106,
#  3.3157894736842106,
#  3.526315789473684,
#  3.3684210526315788,
#  3.473684210526316,
#  3.3684210526315788]

# %%
list(dfPromedios.iloc[1,:])[1:]
# Out:
# [3.1666666666666665,
#  3.333333333333333,
#  2.833333333333333,
#  3.6666666666666665,
#  3.333333333333333,
#  3.1666666666666665,
#  3.1666666666666665,
#  3.0,
#  3.1666666666666665,
#  3.6666666666666665]

# %%
dfPromedios.columns.values.tolist()[1:]
# Out:
# ['Pregunta_1',
#  'Pregunta_2',
#  'Pregunta_3',
#  'Pregunta_4',
#  'Pregunta_5',
#  'Pregunta_6',
#  'Pregunta_7',
#  'Pregunta_8',
#  'Pregunta_9',
#  'Pregunta_10']

# %%
dfPromedios.iloc[3,:][0]
# Out:
# 'ANA LUISA CHÁVEZ GARCÍA'

# %%
from Utilidades import *

# %%
nombre = 'testbar.png'
graficar_Promedio_docentes(dfPromedios,5,nombre)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ROILHI~1\AppData\Local\Temp/ipykernel_9912/508167626.py in <module>
#       1 nombre = 'testbar.png'
# ----> 2 graficar_Promedio_docentes(dfPromedios,5,nombre)
#
# NameError: name 'graficar_Promedio_docentes' is not defined
